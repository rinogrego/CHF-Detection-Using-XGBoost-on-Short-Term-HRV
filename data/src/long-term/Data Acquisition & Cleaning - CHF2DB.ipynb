# %%
# !pip install wfdb
# !pip install hrv-analysis
# !pip install py-ecg-detectors
# !pip install neurokit2

from google.colab import output
output.clear()

print("Packages installed successfully!")
# Out:
# Packages installed successfully!

# %%
import pprint
import os
import datetime

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import wfdb
import hrvanalysis
import ecgdetectors
import hrv
import neurokit2 as nk

# %% [markdown]
# ## Congestive Heart Failure RR Interval Database
#
# https://physionet.org/content/chf2db/1.0.0/

# %%
# DOWNLOAD_PATH = "https://physionet.org/content/chf2db/1.0.0/"
# SAVE_DIR = "/content/drive/MyDrive/Projects/HRV/dataset"
# !wget -r -N -c -np $DOWNLOAD_PATH -P $SAVE_DIR

# !wget -r -N -c -np https://physionet.org/files/chf2db/1.0.0/ -P /content/dataset

# %%
# CHF2DB_COLAB_DIR = ...
CHF2DB_GDRIVE_DIR = "/content/drive/MyDrive/Projects/HRV/dataset/physionet.org/files/"
# !cp -R /content/dataset/physionet.org/files/* $CHF2DB_GDRIVE_DIR
# Out:
# cp: cannot stat '/content/dataset/physionet.org/files/*': No such file or directory

# %%
rec = wfdb.get_record_list('chf2db')
print(rec)
# Out:
# ['chf201', 'chf202', 'chf203', 'chf204', 'chf205', 'chf206', 'chf207', 'chf208', 'chf209', 'chf210', 'chf211', 'chf212', 'chf213', 'chf214', 'chf215', 'chf216', 'chf217', 'chf218', 'chf219', 'chf220', 'chf221', 'chf222', 'chf223', 'chf224', 'chf225', 'chf226', 'chf227', 'chf228', 'chf229']

# %%
# CHF2DB_DIR = "/content/dataset/physionet.org/files/chf2db/1.0.0/"
CHF2DB_DIR = "/content/drive/MyDrive/Projects/HRV/dataset/physionet.org/files/chf2db/1.0.0/"

# %%
FS = 128
h = wfdb.rdheader(os.path.join(CHF2DB_DIR, "chf201"))
h.__dict__
# Out:
# {'record_name': 'chf201',
#  'n_sig': 0,
#  'fs': 128,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 0,
#  'base_time': None,
#  'base_date': None,
#  'comments': ['Age: 55  Sex: M  NYHA class: III'],
#  'sig_name': None,
#  'p_signal': None,
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': None,
#  'fmt': None,
#  'samps_per_frame': None,
#  'skew': None,
#  'byte_offset': None,
#  'adc_gain': None,
#  'baseline': None,
#  'units': None,
#  'adc_res': None,
#  'adc_zero': None,
#  'init_value': None,
#  'checksum': None,
#  'block_size': None}

# %%
ann = wfdb.rdann(os.path.join(CHF2DB_DIR, "chf201"), extension='ecg')
pprint.pprint(ann.__dict__.keys())
# Out:
# dict_keys(['record_name', 'extension', 'sample', 'symbol', 'subtype', 'chan', 'num', 'aux_note', 'fs', 'label_store', 'description', 'custom_labels', 'contained_labels', 'ann_len'])

# %%
# ann.__dict__

# %%
# for record in wfdb.get_record_list('chf2db'):
#     print(record)
#     ann = wfdb.rdann(os.path.join(CHF2DB_DIR, record), extension='ecg')
#     r_peaks = ann.sample
#     print("  len(sample):", len(r_peaks))

# %%
pd.Series(ann.symbol).unique()
# index_wave = list(ann.symbol).index('~')
# index_wave
# Out:
# array(['N', '~', 'A', 'V'], dtype=object)

# %%
start_time = datetime.datetime.now()

FS = 128

chf2db = {}
for record in wfdb.get_record_list('chf2db'):
    try:
        output.clear()
        print("Record:", record)
        ann = wfdb.rdann(os.path.join(CHF2DB_DIR, record), extension='ecg')
        record_hea = wfdb.rdheader(os.path.join(CHF2DB_DIR, record))

        r_peaks = np.array(ann.sample, dtype=np.float32)
        annotation = np.array(ann.symbol)

        # counting ectopic beats
        abnormal_beat_num = 0
        for _sym, _count in np.transpose(np.unique(annotation, return_counts=True)):
            if _sym != 'N':
                abnormal_beat_num += int(_count)
            if _sym == 'N':
                normal_beat_num = int(_count)
        normal_beats_ratio = normal_beat_num / (normal_beat_num + abnormal_beat_num)

        # check & replace ectopic beat with np.nan
        for idx, ann in enumerate(annotation):
            if str(ann).upper() != 'N':
                r_peaks[idx] = np.nan
        # interpolate
        r_peaks = hrvanalysis.preprocessing.interpolate_nan_values(r_peaks)

        # retrieve rr_interval from distance between 2 r_peak points
        rri = [r_peaks[i+1] - r_peaks[i] for i in range(len(r_peaks) - 1)]
        # convert the unit from freq_sample to milisecond
        rri = list(np.array(rri) * 1000 / FS)
        print("  len(r_peaks)           :", len(r_peaks))
        print("  len(rri)               :", len(rri))

        rri = hrvanalysis.preprocessing.remove_outliers(
            rri,
            low_rri = 300,
            high_rri = 2000,
        )
        nni = hrvanalysis.preprocessing.interpolate_nan_values(rri)

        # remove nan values if exists
        nni = [val for val in nni if np.isfinite(val)]
        print("  len(nni)               :", len(nni))
        time_domain = hrvanalysis.extract_features.get_time_domain_features(nni)
        print("  time_domain computed!")
        freq_domain = hrvanalysis.extract_features.get_frequency_domain_features(nni)
        print("  freq_domain computed!")
        geom = hrvanalysis.extract_features.get_geometrical_features(nni)
        print("  geometrical features computed!")
        poincare = hrvanalysis.extract_features.get_poincare_plot_features(nni)
        print("  poincare features computed!")
        csi_cvi = hrvanalysis.extract_features.get_csi_cvi_features(nni)
        print("  csi cvi computed!")
        # Function computing the sample entropy of the given data.
        # Must use this function on short term recordings, from 1 minute window.
        if len(nni) <= 200:
            # Ref: https://ieeexplore.ieee.org/document/8295257
            # Sample entropy (SampEn), a popularly used “regularity analysis” tool,
            # has restrictions in handling shortterm segments (largely N ≤ 200) of
            # heart rate variability (HRV) data
            sampen = hrvanalysis.extract_features.get_sampen(nni)
            print("  sampen computed!")
        else:
            print("  nn > 200")
            print("  nn is set to NaN")
            sampen = {"sampen": np.nan}


        chf2db[record] = {
            "id": "chf2db-" + str(record),
            "db_source": "chf2db",
            "age": record_hea.comments[0].split()[1],
            "gender": record_hea.comments[0].split()[3],
            "fs": FS,
            "signal_length": np.nan,
            "recording_time_hours": np.nan,
            "recording_time_seconds": np.nan,
            "normal_beats": normal_beat_num,
            "abnormal_beats": abnormal_beat_num,
            "normal_beats_ratio": normal_beats_ratio,
            "rri_length": len(rri),
            "nni_length": len(nni),
            **time_domain,
            **freq_domain,
            **geom,
 7417.96875, 13534.1796875, 13533.203125, 13534.1796875, 3468.75, 3468.75, 3234.375, 3234.375, 226.5625, 226.5625, 261.71875, 261.71875, 242.1875, 242.1875, 238.28125, 238.28125, 226.5625, 226.5625, 2507.8125, 2507.8125, 19812.5, 19812.5, 238.28125, 238.28125, 2175.78125, 2175.78125, 234.375, 234.375, 238.28125, 238.28125, 253.90625, 253.90625, 242.1875, 242.1875, 4414.0625, 4414.0625, 253.90625, 253.90625, 2339.84375, 2339.84375, 242.1875, 242.1875, 234.375, 234.375, 250.0, 250.0, 242.1875, 242.1875, 246.09375, 246.09375, 253.90625, 253.90625, 257.8125, 257.8125, 234.375, 234.375, 2437.5, 2437.5, 10093.75, 10093.75, 238.28125, 238.28125, 246.09375, 246.09375, 2437.5, 2437.5, 2437.5, 2437.5, 246.09375, 246.09375, 3132.8125, 3132.8125, 281.25, 281.25, 2753.90625, 2753.90625, 238.28125, 238.28125, 2644.53125, 2644.53125, 4316.40625, 4316.40625, 2593.75, 2593.75, 9429.6875, 9429.6875, 9429.6875, 2847.65625, 2847.65625, 8523.4375, 8523.4375, 242.1875, 242.1875, 238.28125, 238.28125, 2433.59375, 2433.59375, 9254.8828125, 9255.859375, 9254.8828125, 14101.5625, 14101.5625, 7496.09375, 7496.09375, 2269.53125, 2269.53125, 2480.46875, 2480.46875, 2457.03125, 2457.03125, 5308.59375, 5308.59375, 4761.71875, 4761.71875, 4253.90625, 4253.90625, 8546.875, 8546.875, 2363.28125, 2363.28125, 230.46875, 230.46875, 3324.21875, 3324.21875, 5035.15625, 5035.15625, 10500.0, 10500.0, 250.0, 250.0, 273.4375, 273.4375, 3285.15625, 3285.15625, 234.375, 234.375, 2382.8125, 2382.8125, 257.8125, 257.8125, 5226.5625, 5226.5625, 2617.1875, 2617.1875, 11113.28125, 11113.28125, 2480.46875, 2480.46875, 269.53125, 269.53125, 10652.34375, 10652.34375, 250.0, 250.0, 172418.9453125, 172419.921875, 172418.9453125, 2156.25, 2156.25, 2843.75, 2843.75, 2441.40625, 2441.4 ...
#   len(nni)               : 126158
#   time_domain computed!
#   freq_domain computed!
#   geometrical features computed!
#   poincare features computed!
#   csi cvi computed!
#   nn > 200
#   nn is set to NaN
#   RECORD chf229 SAVED!
# 0:02:00.263064

# %%
# pprint.pprint(chf2db)

# %%
df_chf2db = pd.DataFrame(chf2db).T
df_chf2db
# Out:
#                    id db_source age gender   fs signal_length  \
# chf201  chf2db-chf201    chf2db  55      M  128           NaN
# chf202  chf2db-chf202    chf2db  59      F  128           NaN
# chf203  chf2db-chf203    chf2db  68      M  128           NaN
# chf204  chf2db-chf204    chf2db  62      M  128           NaN
# chf205  chf2db-chf205    chf2db  39      M  128           NaN
# chf206  chf2db-chf206    chf2db  38      F  128           NaN
# chf207  chf2db-chf207    chf2db  62      M  128           NaN
# chf208  chf2db-chf208    chf2db  62      M  128           NaN
# chf209  chf2db-chf209    chf2db  65      M  128           NaN
# chf210  chf2db-chf210    chf2db  43      M  128           NaN
# chf211  chf2db-chf211    chf2db  34      ?  128           NaN
# chf212  chf2db-chf212    chf2db  54      ?  128           NaN
# chf213  chf2db-chf213    chf2db  53      ?  128           NaN
# chf214  chf2db-chf214    chf2db  79      ?  128           NaN
# chf215  chf2db-chf215    chf2db  43      ?  128           NaN
# chf216  chf2db-chf216    chf2db  58      ?  128           NaN
# chf217  chf2db-chf217    chf2db  50      ?  128           NaN
# chf218  chf2db-chf218    chf2db  72      ?  128           NaN
# chf219  chf2db-chf219    chf2db  62      ?  128           NaN
# chf220  chf2db-chf220    chf2db  64      ?  128           NaN
# chf221  chf2db-chf221    chf2db  37      ?  128           NaN
# chf222  chf2db-chf222    chf2db  63      ?  128           NaN
# chf223  chf2db-chf223    chf2db  56      ?  128           NaN
# chf224  chf2db-chf224    chf2db  35      ?  128           NaN
# chf225  chf2db-chf225    chf2db  66      ?  128           NaN
# chf226  chf2db-chf226    chf2db  51      ?  128           NaN
# chf227  chf2db-chf227    chf2db  64      ?  128           NaN
# chf228  chf2db-chf228    chf2db  51      ?  128           NaN
# chf229  chf2db-chf229    chf2db  58      ?  128           NaN
#
#        recording_time_hours recording_time_seconds normal_beats  \
# chf201                  NaN                    NaN       112123
# chf202                  NaN                    NaN       109059
# chf203                  NaN                    NaN        98884
# chf204                  NaN                    NaN        96320
# chf205                  NaN                    NaN       133482
# chf206                  NaN                    NaN       124376
# chf207                  NaN                    NaN        94562
# chf208                  NaN                    NaN       105427
# chf209                  NaN                    NaN       108808
# chf210                  NaN                    NaN       139696
# chf211                  NaN                    NaN       127326
# chf212                  NaN                    NaN        99462
# chf213                  NaN                    NaN        94122
# chf214                  NaN                    NaN        72797
# chf215                  NaN                    NaN       142044
# chf216                  NaN                    NaN       101721
# chf217                  NaN                    NaN       105653
# chf218                  NaN                    NaN       102632
# chf219                  NaN                    NaN        90525
# chf220                  NaN                    NaN       136985
# chf221                  NaN                    NaN       100308
# chf222                  NaN                    NaN        99306
# chf223                  NaN                    NaN       107527
# chf224                  NaN                    NaN       134418
# chf225                  NaN                    NaN        91452
# chf226                  NaN                    NaN       129584
# chf227                  NaN                    NaN       101126
# chf228                  NaN                    NaN       117548
# chf229                  NaN                    NaN       123384
#
#        abnormal_beats normal_beats_ratio rri_length nni_length    mean_nni  \
# chf201            110            0.99902     112232     112232  738.033298
# chf202            468           0.995727     109526     109526  676.160191
# chf203           1362           0.986413     100245     100245  749.741337
# chf204           2561             0.9741      98880      98880  750.324849
# chf205           2774           0.979641     136255     136254  579.681412
# chf206          11267           0.916936     135642     135642  554.326831
# chf207          17168           0.846344     111729     111729  621.319778
# chf208           3851            0.96476     109277     109277   790.89659
# chf209            738           0.993263     109545     109542  617.677431
# chf210           2328           0.983608     142023     142023  576.219636
# chf211            720           0.994377     128045     128044  668.840734
# chf212           6546            0.93825     106007     106005  556.917044
# chf213          11618           0.890127     105739     105738   808.19608
# chf214          21572           0.771408      94368      94368  645.923448
# chf215           6665           0.955181     148708     148708  555.778052
pd.read_csv("df_chf2db.csv")
# Out:
#                id db_source  age gender   fs  signal_length  \
# 0   chf2db-chf201    chf2db   55      M  128            NaN
# 1   chf2db-chf202    chf2db   59      F  128            NaN
# 2   chf2db-chf203    chf2db   68      M  128            NaN
# 3   chf2db-chf204    chf2db   62      M  128            NaN
# 4   chf2db-chf205    chf2db   39      M  128            NaN
# 5   chf2db-chf206    chf2db   38      F  128            NaN
# 6   chf2db-chf207    chf2db   62      M  128            NaN
# 7   chf2db-chf208    chf2db   62      M  128            NaN
# 8   chf2db-chf209    chf2db   65      M  128            NaN
# 9   chf2db-chf210    chf2db   43      M  128            NaN
# 10  chf2db-chf211    chf2db   34      ?  128            NaN
# 11  chf2db-chf212    chf2db   54      ?  128            NaN
# 12  chf2db-chf213    chf2db   53      ?  128            NaN
# 13  chf2db-chf214    chf2db   79      ?  128            NaN
# 14  chf2db-chf215    chf2db   43      ?  128            NaN
# 15  chf2db-chf216    chf2db   58      ?  128            NaN
# 16  chf2db-chf217    chf2db   50      ?  128            NaN
# 17  chf2db-chf218    chf2db   72      ?  128            NaN
# 18  chf2db-chf219    chf2db   62      ?  128            NaN
# 19  chf2db-chf220    chf2db   64      ?  128            NaN
# 20  chf2db-chf221    chf2db   37      ?  128            NaN
# 21  chf2db-chf222    chf2db   63      ?  128            NaN
# 22  chf2db-chf223    chf2db   56      ?  128            NaN
# 23  chf2db-chf224    chf2db   35      ?  128            NaN
# 24  chf2db-chf225    chf2db   66      ?  128            NaN
# 25  chf2db-chf226    chf2db   51      ?  128            NaN
# 26  chf2db-chf227    chf2db   64      ?  128            NaN
# 27  chf2db-chf228    chf2db   51      ?  128            NaN
# 28  chf2db-chf229    chf2db   58      ?  128            NaN
#
#     recording_time_hours  recording_time_seconds  normal_beats  \
# 0                    NaN                     NaN        112123
# 1                    NaN                     NaN        109059
# 2                    NaN                     NaN         98884
# 3                    NaN                     NaN         96320
# 4                    NaN                     NaN        133482
# 5                    NaN                     NaN        124376
# 6                    NaN                     NaN         94562
# 7                    NaN                     NaN        105427
# 8                    NaN                     NaN        108808
# 9                    NaN                     NaN        139696
# 10                   NaN                     NaN        127326
# 11                   NaN                     NaN         99462
# 12                   NaN                     NaN         94122
# 13                   NaN                     NaN         72797
# 14                   NaN                     NaN        142044
# 15                   NaN                     NaN        101721
# 16                   NaN                     NaN        105653
# 17                   NaN                     NaN        102632
# 18                   NaN                     NaN         90525
# 19                   NaN                     NaN        136985
# 20                   NaN                     NaN        100308
# 21                   NaN                     NaN         99306
# 22                   NaN                     NaN        107527
# 23                   NaN                     NaN        134418
# 24                   NaN                     NaN         91452
# 25                   NaN                     NaN        129584
# 26                   NaN                     NaN        101126
# 27                   NaN                     NaN        117548
# 28                   NaN                     NaN        123384
#
#     abnormal_beats  normal_beats_ratio  rri_length  nni_length    mean_nni  \
# 0              110            0.999020      112232      112232  738.033298
# 1              468            0.995727      109526      109526  676.160191
# 2             1362            0.986413      100245      100245  749.741337
# 3             2561            0.974100       98880       98880  750.324849
# 23   NYHA class: II     1
# 24  NYHA class: III     1
# 25   NYHA class: II     1
# 26  NYHA class: III     1
# 27  NYHA class: III     1
# 28  NYHA class: III     1

# %%
pd.read_excel("df_chf2db.xlsx")
# Out:
#                id db_source  age gender   fs  signal_length  \
# 0   chf2db-chf201    chf2db   55      M  128            NaN
# 1   chf2db-chf202    chf2db   59      F  128            NaN
# 2   chf2db-chf203    chf2db   68      M  128            NaN
# 3   chf2db-chf204    chf2db   62      M  128            NaN
# 4   chf2db-chf205    chf2db   39      M  128            NaN
# 5   chf2db-chf206    chf2db   38      F  128            NaN
# 6   chf2db-chf207    chf2db   62      M  128            NaN
# 7   chf2db-chf208    chf2db   62      M  128            NaN
# 8   chf2db-chf209    chf2db   65      M  128            NaN
# 9   chf2db-chf210    chf2db   43      M  128            NaN
# 10  chf2db-chf211    chf2db   34      ?  128            NaN
# 11  chf2db-chf212    chf2db   54      ?  128            NaN
# 12  chf2db-chf213    chf2db   53      ?  128            NaN
# 13  chf2db-chf214    chf2db   79      ?  128            NaN
# 14  chf2db-chf215    chf2db   43      ?  128            NaN
# 15  chf2db-chf216    chf2db   58      ?  128            NaN
# 16  chf2db-chf217    chf2db   50      ?  128            NaN
# 17  chf2db-chf218    chf2db   72      ?  128            NaN
# 18  chf2db-chf219    chf2db   62      ?  128            NaN
# 19  chf2db-chf220    chf2db   64      ?  128            NaN
# 20  chf2db-chf221    chf2db   37      ?  128            NaN
# 21  chf2db-chf222    chf2db   63      ?  128            NaN
# 22  chf2db-chf223    chf2db   56      ?  128            NaN
# 23  chf2db-chf224    chf2db   35      ?  128            NaN
# 24  chf2db-chf225    chf2db   66      ?  128            NaN
# 25  chf2db-chf226    chf2db   51      ?  128            NaN
# 26  chf2db-chf227    chf2db   64      ?  128            NaN
# 27  chf2db-chf228    chf2db   51      ?  128            NaN
# 28  chf2db-chf229    chf2db   58      ?  128            NaN
#
#     recording_time_hours  recording_time_seconds  normal_beats  \
# 0                    NaN                     NaN        112123
# 1                    NaN                     NaN        109059
# 2                    NaN                     NaN         98884
# 3                    NaN                     NaN         96320
# 4                    NaN                     NaN        133482
# 5                    NaN                     NaN        124376
# 6                    NaN                     NaN         94562
# 7                    NaN                     NaN        105427
# 8                    NaN                     NaN        108808
# 9                    NaN                     NaN        139696
# 10                   NaN                     NaN        127326
# 11                   NaN                     NaN         99462
# 12                   NaN                     NaN         94122
# 13                   NaN                     NaN         72797
# 14                   NaN                     NaN        142044
# 15                   NaN                     NaN        101721
# 16                   NaN                     NaN        105653
# 17                   NaN                     NaN        102632
# 18                   NaN                     NaN         90525
# 19                   NaN                     NaN        136985
# 20                   NaN                     NaN        100308
# 21                   NaN                     NaN         99306
# 22                   NaN                     NaN        107527
# 23                   NaN                     NaN        134418
# 24                   NaN                     NaN         91452
# 25                   NaN                     NaN        129584
# 26                   NaN                     NaN        101126
# 27                   NaN                     NaN        117548
# 28                   NaN                     NaN        123384
#
#     abnormal_beats  normal_beats_ratio  rri_length  nni_length    mean_nni  \
# 17    NYHA class: I     1
# 18  NYHA class: III     1
# 19   NYHA class: II     1
# 20    NYHA class: I     1
# 21  NYHA class: III     1
# 22  NYHA class: III     1
# 23   NYHA class: II     1
# 24  NYHA class: III     1
# 25   NYHA class: II     1
# 26  NYHA class: III     1
# 27  NYHA class: III     1
# 28  NYHA class: III     1

# %% [markdown]
# ## Coret2an

# %%
def fill_interpolate(RR, t, k, i):
    RR_len = len(RR)
    if k == 0:
        # single nan
        if i == 0:
            # at the beginning
            RR[i] = RR[i+1]
        elif i+1 == RR_len:
            # at the end
            RR[i] = RR[i-1]
    else:
        RR[i] = (RR[t+k+1] - RR[t-1])/(t + k + 1 - (t - 1)) * (i - t + 1) + RR[t-1]
    return RR

def nearest_interpolate(RR):
    RR = np.array(RR)
    nan_indexes = np.argwhere(np.isnan(t_RR))[:, 0]
    print("nan_indexes", nan_indexes)

    consecutive_indexes = []
    ci = []
    for idx, nan_idx in enumerate(nan_indexes):
        if nan_idx == nan_indexes[-1]:
            print("nan_indexes terakhir")
            ci.append(nan_idx)
            print(ci)
            consecutive_indexes.append(ci)
            ci = []
        elif len(ci) == 0 or nan_indexes[idx+1] - nan_idx == 1:
            print("masuk")
            ci.append(nan_idx)
            print(ci)
        elif nan_indexes[idx+1] - nan_idx > 1:
            print("nan_indexes tengah terakhir")
            ci.append(nan_idx)
            print(ci)
            consecutive_indexes.append(ci)
            ci = []
            print("reset")
            print(ci)

    print(consecutive_indexes)
    for ci in consecutive_indexes:
        t = ci[0]
        k = ci[-1] - t
        for i in range(t, t+k+1):
            RR = fill_interpolate(RR, t, k, i)

    # t = nan_indexes[0][0]
    # k = nan_indexes[-1][0] - t
    # print(t, k)
    # for i in nan_indexes:
    #     RR = fill_interpolate(RR, t, k, i[0])

    return RR

# %%
t_RR = [100, 200, 150, np.nan, np.nan, np.nan, 350, 100, 100, np.nan, np.nan, 400, 500, np.nan, np.nan]
t_RR = np.array(t_RR)

# %%
# first K or last K np.nan still give error
nearest_interpolate(t_RR)
# Out:
# nan_indexes [ 3  4  5  9 10 13 14]
# masuk
# [3]
# masuk
# [3, 4]
# nan_indexes tengah terakhir
# [3, 4, 5]
# reset
# []
# masuk
# [9]
# nan_indexes tengah terakhir
# [9, 10]
# reset
# []
# masuk
# [13]
# nan_indexes terakhir
# [13, 14]
# [[3, 4, 5], [9, 10], [13, 14]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-302-825424146509> in <cell line: 1>()
# ----> 1 interpolate(t_RR)
#
# <ipython-input-298-73216482d959> in interpolate(RR)
#      42         k = ci[-1] - t
#      43         for i in range(t, t+k+1):
# ---> 44             RR = fill_interpolate(RR, t, k, i)
#      45
#      46     # t = nan_indexes[0][0]
#
# <ipython-input-298-73216482d959> in fill_interpolate(RR, t, k, i)
#       7             RR[i] = RR[i-1]
#       8     else:
# ----> 9         RR[i] = (RR[t+k+1] - RR[t-1])/(t + k + 1 - (t - 1)) * (i - t + 1) + RR[t-1]
#      10     return RR
#      11
#
# IndexError: index 15 is out of bounds for axis 0 with size 15
